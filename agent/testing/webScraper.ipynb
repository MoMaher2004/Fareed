# %%
import undetected_chromedriver as uc
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By

# %%
options = uc.ChromeOptions()

options.add_argument("--user-data-dir=/home/maher/.config/google-chrome/selenium-profile")
options.add_argument("--start-maximized")

driver = uc.Chrome(options=options)

# %%
driver.get("https://facebook.com")

# %%
email = driver.find_element(By.CSS_SELECTOR, "input[name='email']")
email.click()
email.send_keys("mohamed.a.maher2004@gmail.com")

# %%
password = driver.find_element(By.CSS_SELECTOR, "input[name='pass']")
password.click()
password.send_keys("mohamed.a.maher2004@gmail.com")

# %%
login_button = driver.find_elements(
    By.CSS_SELECTOR,
    ".html-div"
)[0]

login_button.click()
